# %%
baseurl = "http://api.weatherapi.com/v1"
my_key = "Real_api_key"

# %%
#http://api.weatherapi.com/v1/current.json?key=<my_key>&q=London

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd

# %%
city = "Louisville"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={my_key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1778463176,
#   'localtime': '2026-05-10 21:32'},
#  'current': {'last_updated_epoch': 1778463000,
#   'last_updated': '2026-05-10 21:30',
#   'temp_c': 21.1,
#   'temp_f': 70.0,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 7.8,
#   'wind_kph': 12.6,
#   'wind_degree': 10,
#   'wind_dir': 'N',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.02,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 39,
#   'cloud': 25,
#   'feelslike_c': 21.1,
#   'feelslike_f': 70.0,
#   'windchill_c': 18.9,
#   'windchill_f': 66.1,
#   'heatindex_c': 19.3,
#   'heatindex_f': 66.7,
#   'dewpoint_c': 6.7,
#   'dewpoint_f': 44.0,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
# ...

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (73.9, 38)

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={my_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Lexington")

# %%
cities = ["kapaa", "Louisville", "Morehead", "Lihue", "New York"]
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={my_key}&q={city}"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "city": data['location']['name'],
            "Temparature": data['current']['temp_f'],
            "Condition": data['current']['condition']['text'],
            "humidity": data['current']['wind_mph']    })

    else:
        print("Error fetching data")

# %%
weather_data
# Out:
# [{'city': 'Kapaa',
#   'Temparature': 79.0,
#   'Condition': 'Partly cloudy',
#   'humidity': 14.8},
#  {'city': 'Louisville',
#   'Temparature': 73.9,
#   'Condition': 'Sunny',
#   'humidity': 6.9},
#  {'city': 'Morehead',
#   'Temparature': 78.1,
#   'Condition': 'Cloudy',
#   'humidity': 5.8},
#  {'city': 'Lihue',
#   'Temparature': 79.0,
#   'Condition': 'Partly cloudy',
#   'humidity': 14.8},
#  {'city': 'New York',
#   'Temparature': 70.0,
#   'Condition': 'Partly cloudy',
#   'humidity': 7.6}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#          city  Temparature      Condition  humidity
# 0       Kapaa         79.0  Partly cloudy      14.3
# 1  Louisville         73.9          Sunny       7.6
# 2    Morehead         75.5           Mist       4.7
# 3       Lihue         79.0  Partly cloudy      14.3
# 4    New York         70.0  Partly cloudy       6.5

# %%
weather_df.to_csv("sample_weather_data.csv", index=False)
